# %% [markdown]
# # Testing live market data collection
#
# These methods will soon be used in live trading with researched strategies

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time
from datetime import datetime

headers = {
    'User-agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36"
}

starttime = time.time()
data = {'Time_stamp' : [], 'mark_close' : [],'MA20':[]}
ma20 = 0
df = pd.DataFrame(data)

# scraped_share = input('please input share to be searched: \n')

df = df.iloc[0:0]

def current_price_caller(share_code):
    url = 'https://finance.yahoo.com/quote/' + share_code + '/'
    r = requests.get(url,{'headers':headers})
    soup = bs4.BeautifulSoup(r.text,{'html.parser'})
    result = soup.find_all('div',{'class' : 'D(ib) Mend(20px)'})[0].find('span').text
    result = result .replace(',','')
    result = float(result)
    return result

while True:
    price = current_price_caller('CL=F')
    now = datetime.now()
    now = now.strftime("%H:%M:%S")
    
    if len(df) >= 20:
        ma20 = 0
        for i in range(1,21):
            ma20 = ma20 + df.iloc[len(df) - i]['mark_close']
        ma20 = ma20 / 20
    
    append_list = [now,price,ma20]
    df.loc[len(df)] = append_list
    print(append_list)
    
    time.sleep(1.0 - ((time.time() - starttime) % 1.0))
# Out:
# ['19:00:37', 68.76, 0]
# ['19:00:38', 68.76, 0]
# ['19:00:39', 68.76, 0]
# ['19:00:41', 68.76, 0]
# ['19:00:41', 68.75, 0]
# ['19:00:42', 68.75, 0]
# ['19:00:43', 68.75, 0]
# ['19:00:44', 68.75, 0]
# ['19:00:45', 68.75, 0]
# ['19:00:46', 68.75, 0]
# ['19:00:47', 68.75, 0]
# ['19:00:48', 68.75, 0]
# ['19:00:49', 68.75, 0]
# ['19:00:50', 68.76, 0]
# ['19:00:52', 68.76, 0]
# ['19:00:56', 69.49, 0]
# ['19:01:02', 69.49, 0]
# ['19:01:08', 69.49, 0]
# ['19:01:13', 69.49, 0]
# ['19:01:15', 69.49, 0]
# ['19:01:19', 69.49, 68.938]
# ['19:01:25', 69.49, 68.9745]
# ['19:01:30', 69.49, 69.011]
# ['19:01:35', 69.49, 69.0475]
# ['19:01:39', 69.49, 69.08399999999999]
# ['19:01:42', 69.49, 69.12100000000001]
# ['19:01:48', 69.49, 69.15799999999999]
# ['19:01:54', 69.49, 69.19500000000001]
# ['19:01:59', 69.49, 69.232]
# ['19:02:01', 69.49, 69.269]
# ---------------------------------------------------------------------------
# ...

# %%
# data = {'Time_stamp' : [], 'mark_close' : []
#        }

# now = datetime.now()
# now = now.strftime("%H:%M:%S")
# append_list = ['*timestamp*',now]

# data = {markclose,timestamp}

# df = pd.DataFrame(data)
# df.loc[len(df)] = append_list

print(df)
print(df.iloc[len(df) - 1]['mark_close'])
# print(df.iloc[len(df) - 21]['mark_close'])

df['MA'] = df.iloc[:,1].rolling(window=3).mean()
print (df)


# if len(df) > 20:
#     for i in range(1,22):
#         sum = sum + df.iloc[len(df) - i]['mark_close']
# Out:
#    Time_stamp  mark_close     MA20
# 0    17:59:25       69.23   0.0000
# 1    17:59:26       69.23   0.0000
# 2    17:59:27       69.23   0.0000
# 3    17:59:28       69.23   0.0000
# 4    17:59:29       69.23   0.0000
# 5    17:59:30       69.23   0.0000
# 6    17:59:31       69.23   0.0000
# 7    17:59:32       69.23   0.0000
# 8    17:59:33       69.23   0.0000
# 9    17:59:34       69.23   0.0000
# 10   17:59:35       69.23   0.0000
# 11   17:59:36       69.23   0.0000
# 12   17:59:37       69.23   0.0000
# 13   17:59:38       69.23   0.0000
# 14   17:59:39       69.23   0.0000
# 15   17:59:40       69.23   0.0000
# 16   17:59:41       69.23   0.0000
# 17   17:59:42       69.23   0.0000
# 18   17:59:43       69.23   0.0000
# 19   17:59:44       69.23   0.0000
# 20   17:59:45       69.23  69.2300
# 21   17:59:46       69.23  69.2300
# 22   17:59:47       69.23  69.2300
# 23   17:59:48       69.23  69.2300
# 24   17:59:49       69.22  69.2300
# 25   17:59:50       69.22  69.2295
# ...

# %%
# now2 = datetime.now() - datetime.timedelta(minutes=5)
import statistics

df_len= len(df)
print(df.loc[df_len - 5:df_len,'mark_close'])

print(df.loc[df_len - 20:df_len - 1,'mark_close'])
print(df.loc[1:df_len,'mark_close'].mean())
ma20 = df.loc[df_len - 20:df_len - 1,'mark_close'].mean()
print(ma20)
# Out:
# 25    69.49
# 26    69.49
# 27    69.49
# 28    69.49
# 29    69.49
# Name: mark_close, dtype: float64
# 10    68.75
# 11    68.75
# 12    68.75
# 13    68.76
# 14    68.76
# 15    69.49
# 16    69.49
# 17    69.49
# 18    69.49
# 19    69.49
# 20    69.49
# 21    69.49
# 22    69.49
# 23    69.49
# 24    69.49
# 25    69.49
# 26    69.49
# 27    69.49
# 28    69.49
# 29    69.49
# Name: mark_close, dtype: float64
# 69.13448275862069
# 69.30600000000001
